# %% [markdown]
# <a href="https://colab.research.google.com/github/glaucio1973/mvp_sprint1/blob/main/Aula_de_Analise_Exploratoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 4) Importando dados de um arquivo .csv no Google Drive

# imports necessários
import pandas as pd
from google.colab import drive

# monta o drive
drive.mount("/content/drive") # neste momento irá aparecer um link do seu GoogleDrive para você clicar e copiar um código de acesso OU apenas um popup de autorização
# Out:
# Mounted at /content/drive

# %%
# carga do dataset através de um arquivo
enem_br = pd.read_csv("drive/MyDrive/datasets/enem_2021.csv",delimiter=';',encoding='ISO-8859-1') # este arquivo deve estar dentro da pasta "datasets" do seu GoogleDrive

# verifica o tipo de iris
print(type(enem_br))

# exibe as 5 primeiras linhas
enem_br.head()
display(enem_br)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        210053865474    2021                5       F                1
# 1        210052384164    2021               12       M                1
# 2        210052589243    2021               13       F                3
# 3        210052128335    2021                3       M                1
# 4        210051353021    2021                2       F                1
# ...               ...     ...              ...     ...              ...
# 3389827  210053249138    2021                7       F                1
# 3389828  210053776013    2021                7       F                1
# 3389829  210052441508    2021               13       F                1
# 3389830  210051139675    2021                7       F                1
# 3389831  210052410399    2021               12       F                2
#
# ...

# %%
enem_br.shape
pd.set_option('display.max_columns', None)
#enem_br.info()
tabela = enem_br.drop(enem_br.columns[[35,36,37,38,40,41,42,43,51,52,53,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,70,72,73,74,75]], axis=1)
display(tabela)
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        210053865474    2021                5       F                1
# 1        210052384164    2021               12       M                1
# 2        210052589243    2021               13       F                3
# 3        210052128335    2021                3       M                1
# 4        210051353021    2021                2       F                1
# ...               ...     ...              ...     ...              ...
# 3389827  210053249138    2021                7       F                1
# 3389828  210053776013    2021                7       F                1
# 3389829  210052441508    2021               13       F                1
# 3389830  210051139675    2021                7       F                1
# 3389831  210052410399    2021               12       F                2
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %%
# Excluindo os alunos que faltaram a prova
tabela = tabela.drop(tabela[tabela['TP_PRESENCA_CN'] == 0].index)
tabela = tabela.drop(tabela[tabela['TP_PRESENCA_CH'] == 0].index)
tabela = tabela.drop(tabela[tabela['TP_PRESENCA_LC'] == 0].index)
tabela = tabela.drop(tabela[tabela['TP_PRESENCA_MT'] == 0].index)
tabela.shape
tabela.describe()
# Out:
#        NU_INSCRICAO     NU_ANO  TP_FAIXA_ETARIA  TP_ESTADO_CIVIL  \
# count  2.240046e+06  2240046.0     2.240046e+06     2.240046e+06
# mean   2.100527e+11     2021.0     4.501351e+00     1.032948e+00
# std    9.969264e+05        0.0     3.537368e+00     3.578061e-01
# min    2.100510e+11     2021.0     1.000000e+00     0.000000e+00
# 25%    2.100519e+11     2021.0     2.000000e+00     1.000000e+00
# 50%    2.100527e+11     2021.0     3.000000e+00     1.000000e+00
# 75%    2.100536e+11     2021.0     5.000000e+00     1.000000e+00
# max    2.100545e+11     2021.0     2.000000e+01     4.000000e+00
#
#         TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# count  2.240046e+06      2.240046e+06     2.240046e+06     2.240046e+06
# mean   1.985505e+00      1.026741e+00     1.715718e+00     2.004511e+00
# std    1.022835e+00      2.070350e-01     7.411417e-01     3.795058e+00
# min    0.000000e+00      0.000000e+00     1.000000e+00     0.000000e+00
# ...
